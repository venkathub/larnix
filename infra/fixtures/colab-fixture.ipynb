# %% [markdown]
# # Colab fixture — GPU-notebook pattern proof
#
# **This is not a lesson.** It is a minimal fixture that proves the Larnix
# "Open in Colab" button pattern and the GPU-notebook CI policy: GPU/`colab`
# notebooks are **not** executed in CI — they are manually run on Colab and the
# run is recorded in the PR (see `docs/RUNBOOK.md`).

# %%
import sys
print('Python', sys.version.split()[0])

# %%
# On a Colab GPU runtime this shows the allocated GPU.
# (Commented so the fixture never requires a GPU; uncomment when run on Colab.)
# !nvidia-smi
