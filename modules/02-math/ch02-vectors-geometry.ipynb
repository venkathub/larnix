# %% [raw]
# ---
# title: "Vectors & geometry (CI twin)"
# module: "M2 — Math You Actually Need"
# chapter: 2
# difficulty: "beginner"
# prereqs:
#   - "M2 Ch1 — Why math for AI"
# learning_objectives:
#   - "Read a 2D vector [x, y] as both a point and an arrow from the origin"
#   - "Add and scale vectors, and explain each move as a picture"
#   - "Compute the length (magnitude) of a vector with sqrt(x*x + y*y)"
# compute: "browser"
# status: "stable"
# last_reviewed: "2026-06-29"
# est_minutes: 16
# ---

# %% [markdown]
# **CI twin of `ch02-vectors-geometry.qmd`.** Generated by `infra/ci/make_twin.py` (P1-D10); do not edit by hand. It runs the chapter's worked example and exercise solutions under CPython so the R10 gate proves they work (DECISIONS D0010).

# %%
# Make the single-sourced grader importable under CPython (no paste; P1-D9).
import sys, pathlib
for _p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]:
    if (_p / 'lib' / 'grader.py').exists():
        sys.path.insert(0, str(_p))
        break
from lib.grader import run_tests

# %%
import matplotlib.pyplot as plt

a = [2, 1]
b = [1, 3]

fig, ax = plt.subplots(figsize=(4, 4))
for v, color in [(a, "tab:blue"), (b, "tab:orange")]:
    ax.annotate(
        "",
        xy=(v[0], v[1]),
        xytext=(0, 0),
        arrowprops=dict(arrowstyle="->", color=color, lw=2),
    )
    ax.text(v[0] + 0.1, v[1] + 0.1, f"({v[0]}, {v[1]})")

ax.set_xlim(-0.5, 4)
ax.set_ylim(-0.5, 4)
ax.axhline(0, color="gray", lw=0.5)
ax.axvline(0, color="gray", lw=0.5)
ax.set_aspect("equal")
ax.grid(True, alpha=0.3)
ax.set_title("Two vectors from the origin")
plt.show()

# %%
a = [2, 1]
b = [1, 3]

len_a = (a[0] * a[0] + a[1] * a[1]) ** 0.5
len_b = (b[0] * b[0] + b[1] * b[1]) ** 0.5
print(f"length of {a} = {round(len_a, 2)}")
print(f"length of {b} = {round(len_b, 2)}")

# %%
def vector_add(a, b):
    return [a[0] + b[0], a[1] + b[1]]

run_tests([
    ("[1,2] + [3,4]", vector_add([1, 2], [3, 4]), [4, 6]),
    ("[0,0] + [5,-2]", vector_add([0, 0], [5, -2]), [5, -2]),
])

run_tests([
    ("[1,2] + [3,4]", vector_add([1, 2], [3, 4]), [4, 6]),
    ("[0,0] + [5,-2]", vector_add([0, 0], [5, -2]), [5, -2]),
])

# %%
def magnitude(v):
    return (v[0] * v[0] + v[1] * v[1]) ** 0.5

run_tests([
    ("length of [3,4]", magnitude([3, 4]), 5.0),
    ("length of [0,0]", magnitude([0, 0]), 0.0),
    ("length of [6,8]", magnitude([6, 8]), 10.0),
])

run_tests([
    ("length of [3,4]", magnitude([3, 4]), 5.0),
    ("length of [0,0]", magnitude([0, 0]), 0.0),
    ("length of [6,8]", magnitude([6, 8]), 10.0),
])
