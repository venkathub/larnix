# %% [raw]
# ---
# title: "Control flow (CI twin)"
# module: "M1 — Python for AI"
# chapter: 2
# difficulty: "beginner"
# prereqs:
#   - "M1 Ch1 — Variables & types"
# learning_objectives:
#   - "Choose a branch with if / elif / else"
#   - "Walk a collection with a for loop and repeat on a condition with while"
#   - "Combine a loop and a condition to count or filter rows of data"
# compute: "browser"
# status: "stable"
# last_reviewed: "2026-06-29"
# est_minutes: 18
# ---

# %% [markdown]
# **CI twin of `ch02-control-flow.qmd`.** Generated by `infra/ci/make_twin.py` (P1-D10); do not edit by hand. It runs the chapter's worked example and exercise solutions under CPython so the R10 gate proves they work (DECISIONS D0010).

# %%
# Make the single-sourced grader importable under CPython (no paste; P1-D9).
import sys, pathlib
for _p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]:
    if (_p / 'lib' / 'grader.py').exists():
        sys.path.insert(0, str(_p))
        break
from lib.grader import run_tests

# %%
days = [
    ("2026-01-01", 7500),
    ("2026-01-02", 8200),
    ("2026-01-03", 5400),
    ("2026-01-04", 9100),
    ("2026-01-05", 8000),
]

active_days = 0
for date, steps in days:
    if steps >= 8000:
        label = "active"
        active_days += 1
    elif steps >= 6000:
        label = "ok"
    else:
        label = "low"
    print(date, steps, "->", label)

print("Active days (>= 8000):", active_days)

# %%
streak = 0
i = 0
while i < len(days) and days[i][1] >= 7000:
    streak += 1
    i += 1

print("Opening streak of days with >= 7000 steps:", streak)

# %%
def label_day(steps):
    if steps >= 8000:
        return "active"
    return "low"

run_tests([
    ("9000 is active", label_day(9000), "active"),
    ("exactly 8000 is active", label_day(8000), "active"),
    ("5000 is low", label_day(5000), "low"),
])

# %%
def count_active(days, goal):
    count = 0
    for date, steps in days:
        if steps >= goal:
            count += 1
    return count

run_tests([
    ("two active", count_active([("a", 7000), ("b", 8200), ("c", 9000)], 8000), 2),
    ("none active", count_active([("a", 100)], 8000), 0),
    ("all active", count_active([("a", 8000), ("b", 9000)], 8000), 2),
])
